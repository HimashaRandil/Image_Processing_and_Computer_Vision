# %%
# Deepface
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 11.6 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=5f38024f340790cc2f51decd948b004b1574189fa92cbb86386ed2681016cdb9
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
import cv2 # Use to deal with images
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# !wget https://as2.ftcdn.net/v2/jpg/01/85/04/85/1000_F_185048528_i9zX0FC3Q8iDNb2E5hanWzN0KeJSXSy6.jpg
# Out:
# --2024-03-22 15:56:52--  https://as2.ftcdn.net/v2/jpg/01/85/04/85/1000_F_185048528_i9zX0FC3Q8iDNb2E5hanWzN0KeJSXSy6.jpg
# Resolving as2.ftcdn.net (as2.ftcdn.net)... 151.101.1.167, 151.101.65.167, 151.101.129.167, ...
# Connecting to as2.ftcdn.net (as2.ftcdn.net)|151.101.1.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 158292 (155K) [image/jpeg]
# Saving to: ‘1000_F_185048528_i9zX0FC3Q8iDNb2E5hanWzN0KeJSXSy6.jpg’
#
# 1000_F_185048528_i9 100%[===================>] 154.58K  --.-KB/s    in 0.03s
#
# 2024-03-22 15:56:53 (5.84 MB/s) - ‘1000_F_185048528_i9zX0FC3Q8iDNb2E5hanWzN0KeJSXSy6.jpg’ saved [158292/158292]

# %%
img = cv2.imread('/content/img.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667>

# %%
result = DeepFace.analyze(img,actions=['emotion','age'], enforce_detection=False)
# Out:
# Action: age:   0%|          | 0/2 [00:00<?, ?it/s]
# 24-03-22 16:11:53 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   0%|          | 1.05M/539M [00:00<00:54, 9.95MB/s]
#   1%|          | 3.15M/539M [00:00<00:35, 14.9MB/s]
#   1%|          | 6.29M/539M [00:00<00:24, 21.3MB/s]
#   2%|▏         | 10.5M/539M [00:00<00:18, 28.3MB/s]
#   3%|▎         | 17.3M/539M [00:00<00:12, 41.7MB/s]
#   5%|▌         | 28.3M/539M [00:00<00:08, 63.1MB/s]
#   8%|▊         | 45.1M/539M [00:00<00:05, 95.3MB/s]
#  13%|█▎        | 70.3M/539M [00:00<00:03, 143MB/s]
#  18%|█▊        | 96.5M/539M [00:00<00:02, 180MB/s]
#  23%|██▎       | 122M/539M [00:01<00:02, 201MB/s]
#  27%|██▋       | 146M/539M [00:01<00:01, 214MB/s]
#  32%|███▏      | 171M/539M [00:01<00:01, 222MB/s]
# ...

# %%
print(result)
# Out:
# [{'emotion': {'angry': 4.049713255710463e-10, 'disgust': 3.3954363893960856e-13, 'fear': 3.2912791936290375e-08, 'happy': 99.99476671218872, 'sad': 3.430586730246432e-05, 'surprise': 1.823611484041976e-07, 'neutral': 0.00519841123605147}, 'dominant_emotion': 'happy', 'region': {'x': 387, 'y': 101, 'w': 227, 'h': 227, 'left_eye': (457, 189), 'right_eye': (540, 196)}, 'face_confidence': 0.9, 'age': 26}]
